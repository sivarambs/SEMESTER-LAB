# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install apyori
from apyori import apriori

# %%
data = pd.read_csv('basket_items.csv',header=None,error_bad_lines=False)
data
# Out:
# b'Skipping line 6: expected 4 fields, saw 5\nSkipping line 8: expected 4 fields, saw 5\nSkipping line 11: expected 4 fields, saw 5\nSkipping line 12: expected 4 fields, saw 9\nSkipping line 24: expected 4 fields, saw 5\nSkipping line 25: expected 4 fields, saw 11\nSkipping line 30: expected 4 fields, saw 6\nSkipping line 32: expected 4 fields, saw 7\nSkipping line 33: expected 4 fields, saw 5\nSkipping line 34: expected 4 fields, saw 8\nSkipping line 41: expected 4 fields, saw 6\nSkipping line 42: expected 4 fields, saw 13\nSkipping line 45: expected 4 fields, saw 8\nSkipping line 50: expected 4 fields, saw 10\nSkipping line 54: expected 4 fields, saw 10\nSkipping line 55: expected 4 fields, saw 5\nSkipping line 58: expected 4 fields, saw 7\nSkipping line 59: expected 4 fields, saw 6\nSkipping line 61: expected 4 fields, saw 7\nSkipping line 64: expected 4 fields, saw 5\nSkipping line 70: expected 4 fields, saw 8\nSkipping line 72: expected 4 fields, saw 7\nSkipping line 73: expected
# ...

# %%
data.shape
# Out:
# (6106, 4)

# %%
data.describe()
# Out:
#                  0           1     2              3
# count         6106        3947  2304           1005
# unique         158         149   141            112
# top     whole milk  rolls/buns  soda  shopping bags
# freq           525         307   166            112

# %%
records = []
for i in range(0,6106):
    records.append([str(data.values[i,j]) for j in range(0,4)])

# %%
for sets in records:
    print(sets)
# Out:
# ['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups']
# ['tropical fruit', 'yogurt', 'coffee', 'nan']
# ['whole milk', 'nan', 'nan', 'nan']
# ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads']
# ['other vegetables', 'whole milk', 'condensed milk', 'long life bakery product']
# ['rolls/buns', 'nan', 'nan', 'nan']
# ['potted plants', 'nan', 'nan', 'nan']
# ['whole milk', 'cereals', 'nan', 'nan']
# ['beef', 'nan', 'nan', 'nan']
# ['frankfurter', 'rolls/buns', 'soda', 'nan']
# ['chicken', 'tropical fruit', 'nan', 'nan']
# ['butter', 'sugar', 'fruit/vegetable juice', 'newspapers']
# ['fruit/vegetable juice', 'nan', 'nan', 'nan']
# ['packaged fruit/vegetables', 'nan', 'nan', 'nan']
# ['chocolate', 'nan', 'nan', 'nan']
# ['specialty bar', 'nan', 'nan', 'nan']
# ['other vegetables', 'nan', 'nan', 'nan']
# ['butter milk', 'pastry', 'nan', 'nan']
# ['whole milk', 'nan', 'nan', 'nan']
# ['bottled water', 'canned beer', 'nan', 'nan']
# ['yogurt', 'nan', 'nan', 'nan']
# ...

# %%
association_rules = apriori(records, min_support = 0.005, min_confidence = 0.8, min_lift = 1, min_length = 2)

# %%
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 3

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'nan'}), support=0.8354077956108745, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.8354077956108745, lift=1.0)])

# %%
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    print("Rule :"+ str(item[0]) + "->" + str(item[1]))
    print("Support : {}".format(item[1]))
    print("Confidence : {}".format(item[2][0][2]))
    print("Lift : {}".format(item[2][0][3]))
    print("\n------------------------------------------------\n")
# Out:
# Rule :frozenset({'nan'})->0.8354077956108745
# Support : 0.8354077956108745
# Confidence : 0.8354077956108745
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'nan', 'canned beer'})->0.07451686865378317
# Support : 0.07451686865378317
# Confidence : 0.906374501992032
# Lift : 1.0849485805064394
#
# ------------------------------------------------
#
# Rule :frozenset({'nan', 'photo/film'})->0.008679986898132984
# Support : 0.008679986898132984
# Confidence : 0.8833333333333333
# Lift : 1.0573678363719532
#
# ------------------------------------------------
